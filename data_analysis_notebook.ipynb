# %%
import pandas as pd

# %%
df = pd.read_csv(r"customer_shopping_behavior.csv")

# %%
df.head()

# %%
df.describe(include='all')

# %%
df.isnull().sum()

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.head(10)

# %%
df.rename(columns={'purchase_amount_(usd)': 'purchase_amount'}, inplace=True)

# %%
df.columns

# %%
label = ['Young Adult', 'Adult' , 'Middle-Age', 'Senior']
df['age_group'] = pd.qcut(df['age'], q = 4, labels = label)
df

# %%
#  create column purchase_frequency_days
frequency_mapping = {
    'Fortnightly': 14,
    'Weekly' : 7,
    'Bi-weekly' : 14,
    'Monthly' : 30,
    'Quarterly' : 90,
    'Annually' : 365,
    'Every 3 Months' : 90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)
df[['purchase_frequency_days', 'frequency_of_purchases' ]].head(10)

# %%
(df['discount_applied'] == df['promo_code_used']).all()

# %%
df.drop('promo_code_used', axis = 1)

# %%
pip install psycopg2-binary sqlalchemy

# %%
from sqlalchemy import create_engine

#connect to your Postgresql 
# replace the placeholder with actual details .
username ="postgres"
password = "Postgres%40123"
host = "localhost"
port = 5433
database = "customer_behaviour"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

#step 2 : load dataframe into postgres
table_name = "customer"
df.to_sql(table_name, engine , if_exists= "replace" , index= "false")
print(f" data successfully load into table '{table_name}' in database '{database}'")
